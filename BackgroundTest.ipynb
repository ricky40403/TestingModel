# %%
# from utils import datagenerator
from utils.shape import ShapesConfig
from coco import CocoDataset
import matplotlib.pyplot as plt
from utils.datagenerator import data_generator

from keras.applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
import keras.layers as KL
import keras.models as KM
import tensorflow as tf
import numpy as np

from utils.BilinearUpSampling import *
from utils.Mylayers import *
# import utils
# Out:
# Using TensorFlow backend.
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
config = ShapesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE_SHAPES                [[56 56]
#  [28 28]
#  [14 14]
#  [ 7  7]
#  [ 4  4]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [ 0.1  0.1  0.2  0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# GPU_COUNT                      2
# IMAGES_PER_GPU                 4
# IMAGE_MAX_DIM                  224
# IMAGE_MIN_DIM                  224
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [224 224   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.002
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [ 123.7  116.8  103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           shapes
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              2
# RPN_BBOX_STD_DEV               [ 0.1  0.1  0.2  0.2]
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %%
dataset_train = CocoDataset()
dataset_train.load_coco('coco_dataset/', "val")
dataset_train.prepare()
# Out:
# loading annotations into memory...
# Done (t=0.68s)
# creating index...
# index created!

# %%
train_generator = data_generator(dataset_train, config, shuffle=True,batch_size=config.BATCH_SIZE,use_background=True)

# %%
############################################################
#  Resnet Graph
############################################################

# Code adopted from:
# https://github.com/fchollet/deep-learning-models/blob/master/resnet50.py

def identity_block(input_tensor, kernel_size, filters, stage, block,
                   use_bias=True):
    """The identity_block is the block that has no conv layer at shortcut
    # Arguments
        input_tensor: input tensor
        kernel_size: defualt 3, the kernel size of middle conv layer at main path
        filters: list of integers, the nb_filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    """
    nb_filter1, nb_filter2, nb_filter3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = KL.Conv2D(nb_filter1, (1, 1), name=conv_name_base + '2a',
                  use_bias=use_bias)(input_tensor)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter2, (kernel_size, kernel_size), padding='same',
                  name=conv_name_base + '2b', use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter3, (1, 1), name=conv_name_base + '2c',
                  use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    x = KL.Add()([x, input_tensor])
    x = KL.Activation('relu', name='res' + str(stage) + block + '_out')(x)
    return x


def conv_block(input_tensor, kernel_size, filters, stage, block,
               strides=(2, 2), use_bias=True):
    """conv_block is the block that has a conv layer at shortcut
    # Arguments
        input_tensor: input tensor
        kernel_size: defualt 3, the kernel size of middle conv layer at main path
        filters: list of integers, the nb_filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    Note that from stage 3, the first conv layer at main path is with subsample=(2,2)
    And the shortcut should have subsample=(2,2) as well
    """
    nb_filter1, nb_filter2, nb_filter3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'


    x = KL.Conv2D(nb_filter1, (1, 1), strides=strides,
                  name=conv_name_base + '2a', use_bias=use_bias)(input_tensor)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter2, (kernel_size, kernel_size), padding='same',
                  name=conv_name_base + '2b', use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter3, (1, 1), name=conv_name_base +
                  '2c', use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    shortcut = KL.Conv2D(nb_filter3, (1, 1), strides=strides,
                         name=conv_name_base + '1', use_bias=use_bias)(input_tensor)
    shortcut = KL.BatchNormalization(axis=3, name=bn_name_base + '1')(shortcut)

    x = KL.Add()([x, shortcut])
    x = KL.Activation('relu', name='res' + str(stage) + block + '_out')(x)
    return x


def resnet_graph(input_image, architecture, input_shape = None, stage5=False,include_top=True,weights='imagenet'):
    assert architecture in ["resnet50", "resnet101"]
    pool_size = (2,2)

    input_shape = _obtain_input_shape(input_shape,
                                     default_size=224,
                                     min_size=197,
                                     data_format=K.image_data_format(),
                                      require_flatten=include_top,
                                      weights=weights)
    print("input_image : {} ".format(input_image))
     # Stage 1
    x = KL.ZeroPadding2D((3, 3))(input_image)
    x = KL.Conv2D(64, (7, 7), strides=(2, 2), name='conv1', use_bias=True)(x)
    x = KL.BatchNormalization(axis=3, name='bn_conv1')(x)
    x = KL.Activation('relu')(x)
    C1 = x = KL.MaxPooling2D((3, 3), strides=(2, 2), padding="same")(x)
    
#     C1 = x , mask_1 = MaxPoolingWithArgmax2D((3,3))(x)
   
    
    print("C1 : {} ".format(C1))
    # Stage 2
    x = conv_block(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='b')
    C2 = x = identity_block(x, 3, [64, 64, 256], stage=2, block='c')
    
    #C2 , mask_2 = MaxPoolingWithArgmax2D((2,2))(x)
    print("C2 : {} ".format(C2))
    
    # Stage 3
    x = conv_block(x, 3, [128, 128, 512], stage=3, block='a')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='b')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='c')
    C3 = x = identity_block(x, 3, [128, 128, 512], stage=3, block='d')
    
    #C3 , mask_3 = MaxPoolingWithArgmax2D((2,2))(x)
    print("C3 : {} ".format(C3))
    
    # Stage 4
    x = conv_block(x, 3, [256, 256, 1024], stage=4, block='a')
    block_count = {"resnet50": 5, "resnet101": 22}[architecture]
    for i in range(block_count):
        x = identity_block(x, 3, [256, 256, 1024], stage=4, block=chr(98 + i))
    C4 = x
    
    #C4 , mask_4 = MaxPoolingWithArgmax2D((2,2))(x)
    
    print("C4 : {} ".format(C4))
    # Stage 5
    if stage5:
        x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
        x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
        C5 = x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')
    else:
        C5 = None
        
#     C5 , mask_5 = MaxPoolingWithArgmax2D((2,2))(x)
    print("C5 : {} ".format(C5))
    
    
    
    xfc = KL.AveragePooling2D((7,7), name='avg_pool')(x)
    xfc = KL.Flatten()(xfc)
    print("xfc Flatten : {} ".format(xfc))
    xfc_out = xfc
    model6 = KM.Model(input_image,xfc)
    
#     xfc = KL.Dense(2048, activation='softmax', name='fc1000')(xfc)
    xfc = KL.Dense(1000, activation='softmax', name='fc1000')(xfc)
    print("xfc Dense : {} ".format(xfc))    

    model = KM.Model(input_image,xfc)
    weights_path = 'keras_resnet50_weight.hdf5'
    model.load_weights(weights_path,by_name=True)
    
    return model,C1,C2,C3,C4,C5#,mask_1#,mask_2,mask_3,mask_4

# %%
def side_branch(x, factor):
    x = Conv2D(1, (1, 1), activation=None, padding='same')(x)

    kernel_size = (2*factor, 2*factor)
    x = Conv2DTranspose(1, kernel_size, strides=factor, padding='same', use_bias=False, activation=None)(x)

    return x

# %%
def generate_model(input_image):
    #resnet
    res_model,C1,C2,C3,C4,C5 = resnet_graph(input_image, "resnet50", stage5=True)
    
#     for layer in res_model.layers:
#         layer.trainable=False
    
    S1 = side_branch(C1,1)
    S2 = side_branch(C2,1)
    S3 = side_branch(C3,2)
    S4 = side_branch(C4,4)
    S5 = side_branch(C5,8)
    
    
    ###########################################################
    # 7*7 layer
    ###########################################################
    
    #7*7*2048
    y1 = KL.Conv2D(2048, (2, 2) , padding="same")(C5)
    y1 = KL.BatchNormalization(axis=3)(y1)
    y1 = KL.Activation('relu')(y1)
    print("y1 : {} ".format(y1))
    
    y1 = KL.Conv2D(81, (2, 2) , padding="same")(y1)
    y1 = KL.BatchNormalization(axis=3)(y1)
    y1 = KL.Activation('relu')(y1)
        
#     y1_pooling = KL.UpSampling2D(size=(8, 8))(y1)
    y1_pooling = BilinearUpSampling2D(target_size=(56, 56))(y1)
    y1_pooling = KL.BatchNormalization(axis=3)(y1_pooling)
    y1_pooling = KL.Activation('relu')(y1_pooling)
    print("y1_pooling : {} ".format(y1_pooling))
    
#     tmp_pooling = KL.UpSampling2D(size=(2, 2))(y1)
    tmp_pooling = BilinearUpSampling2D(target_size=(14, 14))(y1)
    tmp_pooling = KL.BatchNormalization(axis=3)(tmp_pooling)
    tmp_pooling = KL.Activation('relu')(tmp_pooling)
    
    ###########################################################
    # 14*14 layer
    ###########################################################
    
    #14*14*1024
    y2 = KL.Conv2D(1024, (2, 2) , padding="same")(C4)
    y2 = KL.BatchNormalization(axis=3)(y2)
    y2 = KL.Activation('relu')(y2)
    print("y2 : {} ".format(y2))
    
    #14*14*81
    y2 = KL.Conv2D(81, (2, 2) , padding="same")(y2)
    y2 = KL.BatchNormalization(axis=3)(y2)
    y2 = KL.Activation('relu')(y2)
    print("y2 : {} ".format(y2))
    
    y2_pooling = BilinearUpSampling2D(target_size=(56, 56))(y2)
    y2_pooling = KL.BatchNormalization(axis=3)(y2_pooling)
    y2_pooling = KL.Activation('relu')(y2_pooling)
    print("y2_pooling : {} ".format(y2_pooling))
    
    y2 = KL.concatenate([y2,tmp_pooling])
    y2 = KL.Conv2D(81, (2, 2) , padding="same")(y2)
    y2 = KL.BatchNormalization(axis=3)(y2)
    y2 = KL.Activation('relu')(y2)
    print("y2 : {} ".format(y2))
    
    tmp_pooling = BilinearUpSampling2D(target_size=(28, 28))(y2)
    tmp_pooling = KL.BatchNormalization(axis=3)(tmp_pooling)
    tmp_pooling = KL.Activation('relu')(tmp_pooling)
    
    
    ###########################################################
    # 28*28 layer
    ###########################################################
    
    
    #28*28*512
    y3 = KL.Conv2D(512, (2, 2) , padding="same")(C3)
    y3 = KL.BatchNormalization(axis=3)(y3)
    y3 = KL.Activation('relu')(y3)
    print("y3 : {} ".format(y3))
    
    #28*28*81
    y3 = KL.Conv2D(81, (2, 2) , padding="same")(y3)
    y3 = KL.BatchNormalization(axis=3)(y3)
    y3 = KL.Activation('relu')(y3)
    print("y3 : {} ".format(y3))
    
    y3_pooling = BilinearUpSampling2D(target_size=(56, 56))(y3)
    y3_pooling = KL.BatchNormalization(axis=3)(y3_pooling)
    y3_pooling = KL.Activation('relu')(y3_pooling)
    print("y3_pooling : {} ".format(y3_pooling))
    
    y3 = KL.concatenate([y3,tmp_pooling])
    y3 = KL.Conv2D(81, (2, 2) , padding="same")(y3)
    y3 = KL.BatchNormalization(axis=3)(y3)
    y3 = KL.Activation('relu')(y3)
    print("y3 : {} ".format(y3))
    
    tmp_pooling = BilinearUpSampling2D(target_size=(56, 56))(y3)
    tmp_pooling = KL.BatchNormalization(axis=3)(tmp_pooling)
    tmp_pooling = KL.Activation('relu')(tmp_pooling)
    
    
    ###########################################################
    # 56*56 layer
    ###########################################################
        
    #56*56*256
    y4 = KL.Conv2D(256, (2, 2) , padding="same")(C2)
    y4 = KL.BatchNormalization(axis=3)(y4)
    y4 = KL.Activation('relu')(y4)
    print("y4 : {} ".format(y4))
    
    #56*56*81
    y4 = KL.Conv2D(81, (2, 2) , padding="same")(y4)
    y4 = KL.BatchNormalization(axis=3)(y4)
    y4 = KL.Activation('relu')(y4)
    print("y4 : {} ".format(y4))
    
    t = KL.concatenate([S2,S3,S4,S5])
    
    y4 = KL.concatenate([t, y4,tmp_pooling,y1_pooling,y2_pooling,y3_pooling])
    y4 = KL.Conv2D(81, (2, 2) , padding="same")(y4)
    y4 = KL.BatchNormalization(axis=3)(y4)
    y4 = KL.Activation('relu')(y4)
    print("y4 : {} ".format(y4))
    
    y4 = KL.Conv2D(81, (1, 1) , padding="same")(y4)
    y4 = KL.BatchNormalization(axis=3)(y4)
    y4 = KL.Activation('relu')(y4)
    print("y4 : {} ".format(y4))
    
    
    y = KL.Reshape((56*56,81) , input_shape= (56,56,81))(y4)
    print("y : {} ".format(y))
    y = KL.Activation('softmax')(y)
    print("y : {} ".format(y))
    
#     y = KL.Permute((2, 1), input_shape=(3136, 81))(y)
#     print("y : {} ".format(y))
    
    model = KM.Model(input_image,y)
    return model

# %%
input_image = KL.Input(shape=[224,224,3], name="g_input_data")
g_model = generate_model(input_image)
# Out:
# input_image : Tensor("g_input_data_6:0", shape=(?, 224, 224, 3), dtype=float32)
# C1 : Tensor("max_pooling2d_7/MaxPool:0", shape=(?, 56, 56, 64), dtype=float32)
# C2 : Tensor("res2c_out_6/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# C3 : Tensor("res3d_out_6/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# C4 : Tensor("res4f_out_6/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# C5 : Tensor("res5c_out_6/Relu:0", shape=(?, 7, 7, 2048), dtype=float32)
# xfc Flatten : Tensor("flatten_7/Reshape:0", shape=(?, ?), dtype=float32)
# xfc Dense : Tensor("fc1000_6/Softmax:0", shape=(?, 1000), dtype=float32)
# y1 : Tensor("activation_346/Relu:0", shape=(?, 7, 7, 2048), dtype=float32)
# y1_pooling : Tensor("activation_348/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y2 : Tensor("activation_350/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# y2 : Tensor("activation_351/Relu:0", shape=(?, 14, 14, 81), dtype=float32)
# y2_pooling : Tensor("activation_352/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y2 : Tensor("activation_353/Relu:0", shape=(?, 14, 14, 81), dtype=float32)
# y3 : Tensor("activation_355/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# y3 : Tensor("activation_356/Relu:0", shape=(?, 28, 28, 81), dtype=float32)
# y3_pooling : Tensor("activation_357/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y3 : Tensor("activation_358/Relu:0", shape=(?, 28, 28, 81), dtype=float32)
# y4 : Tensor("activation_360/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# y4 : Tensor("activation_361/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y4 : Tensor("activation_362/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y4 : Tensor("activation_363/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y : Tensor("reshape_7/Reshape:0", shape=(?, 3136, 81), dtype=float32)
# y : Tensor("activation_364/truediv:0", shape=(?, 3136, 81), dtype=float32)

# %%
g_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# g_input_data (InputLayer)       (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 230, 230, 3)  0           g_input_data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 64)   0           activation_209[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_210[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_211[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_out (Activation)          (None, 56, 56, 256)  0           add_65[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       res2a_out[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_212[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_213[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  res2a_out[0][0]
# __________________________________________________________________________________________________
# res2b_out (Activation)          (None, 56, 56, 256)  0           add_66[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       res2b_out[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_214[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_215[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  res2b_out[0][0]
# __________________________________________________________________________________________________
# res2c_out (Activation)          (None, 56, 56, 256)  0           add_67[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       res2c_out[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_216[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_217[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      res2c_out[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_out (Activation)          (None, 28, 28, 512)  0           add_68[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       res3a_out[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_218[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_219[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  res3a_out[0][0]
# __________________________________________________________________________________________________
# res3b_out (Activation)          (None, 28, 28, 512)  0           add_69[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       res3b_out[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_220[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_221[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  res3b_out[0][0]
# __________________________________________________________________________________________________
# res3c_out (Activation)          (None, 28, 28, 512)  0           add_70[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       res3c_out[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_222[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_223[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  res3c_out[0][0]
# __________________________________________________________________________________________________
# res3d_out (Activation)          (None, 28, 28, 512)  0           add_71[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      res3d_out[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_224[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_225[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      res3d_out[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_out (Activation)          (None, 14, 14, 1024) 0           add_72[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4a_out[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_226[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_227[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  res4a_out[0][0]
# __________________________________________________________________________________________________
# res4b_out (Activation)          (None, 14, 14, 1024) 0           add_73[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4b_out[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_228[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_229[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  res4b_out[0][0]
# __________________________________________________________________________________________________
# res4c_out (Activation)          (None, 14, 14, 1024) 0           add_74[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4c_out[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_230[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_231[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  res4c_out[0][0]
# __________________________________________________________________________________________________
# res4d_out (Activation)          (None, 14, 14, 1024) 0           add_75[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4d_out[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_232[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_233[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  res4d_out[0][0]
# __________________________________________________________________________________________________
# res4e_out (Activation)          (None, 14, 14, 1024) 0           add_76[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4e_out[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_234[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_235[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  res4e_out[0][0]
# __________________________________________________________________________________________________
# res4f_out (Activation)          (None, 14, 14, 1024) 0           add_77[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      res4f_out[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_236[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_237[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     res4f_out[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_out (Activation)          (None, 7, 7, 2048)   0           add_78[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     res5a_out[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_238[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_239[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  res5a_out[0][0]
# __________________________________________________________________________________________________
# res5b_out (Activation)          (None, 7, 7, 2048)   0           add_79[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     res5b_out[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_240[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_241[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  res5b_out[0][0]
# __________________________________________________________________________________________________
# res5c_out (Activation)          (None, 7, 7, 2048)   0           add_80[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 7, 7, 2048)   16779264    res5c_out[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 7, 7, 2048)   8192        conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 7, 7, 2048)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 14, 14, 1024) 4195328     res4f_out[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 7, 7, 81)     663633      activation_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 14, 14, 1024) 4096        conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 7, 7, 81)     324         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 14, 14, 1024) 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 7, 7, 81)     0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 14, 14, 81)   331857      activation_246[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_26 (Bili (None, 14, 14, 81)   0           activation_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 14, 14, 81)   324         conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 14, 14, 81)   324         bilinear_up_sampling2d_26[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 14, 14, 81)   0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 14, 14, 81)   0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 14, 14, 162)  0           activation_247[0][0]
#                                                                  activation_245[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 28, 28, 512)  1049088     res3d_out[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 14, 14, 81)   52569       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 28, 28, 512)  2048        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 14, 14, 81)   324         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 28, 28, 512)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 14, 14, 81)   0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 28, 28, 81)   165969      activation_251[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_28 (Bili (None, 28, 28, 81)   0           activation_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 28, 28, 81)   324         conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 28, 28, 81)   324         bilinear_up_sampling2d_28[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 28, 28, 81)   0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 28, 28, 81)   0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 28, 28, 162)  0           activation_252[0][0]
#                                                                  activation_250[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 56, 56, 256)  262400      res2c_out[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 28, 28, 81)   52569       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 56, 56, 256)  1024        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 28, 28, 81)   324         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 56, 56, 256)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 28, 28, 81)   0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 56, 56, 1)    257         res2c_out[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 28, 28, 1)    513         res3d_out[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 14, 14, 1)    1025        res4f_out[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 7, 7, 1)      2049        res5c_out[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 56, 56, 81)   83025       activation_256[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_30 (Bili (None, 56, 56, 81)   0           activation_254[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_25 (Bili (None, 56, 56, 81)   0           activation_243[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_27 (Bili (None, 56, 56, 81)   0           activation_247[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_29 (Bili (None, 56, 56, 81)   0           activation_252[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 56, 56, 1)    4           conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 56, 56, 1)    16          conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 56, 56, 1)    64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 56, 56, 1)    256         conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 56, 56, 81)   324         conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 56, 56, 81)   324         bilinear_up_sampling2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 56, 56, 81)   324         bilinear_up_sampling2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 56, 56, 81)   324         bilinear_up_sampling2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 56, 56, 81)   324         bilinear_up_sampling2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 56, 56, 4)    0           conv2d_transpose_22[0][0]
#                                                                  conv2d_transpose_23[0][0]
#                                                                  conv2d_transpose_24[0][0]
#                                                                  conv2d_transpose_25[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 56, 56, 81)   0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 56, 56, 81)   0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 56, 56, 81)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 56, 56, 81)   0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 56, 56, 81)   0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 56, 56, 409)  0           concatenate_19[0][0]
#                                                                  activation_257[0][0]
#                                                                  activation_255[0][0]
#                                                                  activation_244[0][0]
#                                                                  activation_248[0][0]
#                                                                  activation_253[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 56, 56, 81)   132597      concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 56, 56, 81)   324         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 56, 56, 81)   0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 56, 56, 81)   6642        activation_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 56, 56, 81)   324         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 56, 56, 81)   0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 3136, 81)     0           activation_259[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 3136, 81)     0           reshape_5[0][0]
# ==================================================================================================
# Total params: 47,386,733
# Trainable params: 47,323,665
# Non-trainable params: 63,068
# __________________________________________________________________________________________________

# %%
_EPSILON = 1e-7
def epsilon():
    """Returns the value of the fuzz factor used in numeric expressions.
    # Returns
        A float.
    # Example
    ```python
        >>> keras.backend.epsilon()
        1e-07
    ```
    """
    return _EPSILON

def _to_tensor(x, dtype):
    """Convert the input `x` to a tensor of type `dtype`.
    # Arguments
        x: An object to be converted (numpy array, list, tensors).
        dtype: The destination type.
    # Returns
        A tensor.
    """
    return tf.convert_to_tensor(x, dtype=dtype)

# %%
def loss_func(y_true,y_pred):

#     loss = K.categorical_crossentropy(y_true,y_pred)
    y_true = tf.transpose(y_true,[0,2,1])
    y_pred = tf.transpose(y_pred,[0,2,1])

    
    IOU_p = tf.sigmoid(y_pred) 
    IOU_p = tf.greater(IOU_p,tf.reduce_mean(IOU_p))
    IOU_p = tf.cast(IOU_p,tf.bool)
    IOU_t = tf.cast(y_true,tf.bool)
    
    print(IOU_t)
    IOU_and = tf.logical_and(IOU_p , IOU_t)
    IOU_or = tf.logical_or(IOU_p , IOU_t)
    IOU_and = tf.cast(IOU_and,tf.float32)
    IOU_or = tf.cast(IOU_or,tf.float32)    
    IOU_and = tf.reduce_sum(IOU_and,axis=-1)
    IOU_or = tf.reduce_sum(IOU_or,axis=-1)
    
    IOU = tf.divide(IOU_and,IOU_or)
    IOU = tf.clip_by_value(IOU,1/1000,1)
    
    print(IOU)
    
    #let sum equal 1
    y_pred /= tf.reduce_sum(y_pred,axis=len(y_pred.get_shape()) - 1,keep_dims=True)

    # manual computation of crossentropy
    _epsilon = _to_tensor(epsilon(), y_pred.dtype.base_dtype)    
    
    #set y_ture range
    y_pred = tf.clip_by_value(y_pred, _epsilon, 1. - _epsilon)
    
    positive_loss = y_true * tf.log(y_pred) + (1 - y_true) * tf.log(1 - y_pred)
    print(positive_loss)
    
#     loss = K.categorical_crossentropy(y_true,y_pred)    
    loss = tf.reduce_mean(positive_loss,axis=-1)    
    loss = tf.divide(loss,IOU)
    
    
    print(loss)
    

    
    return -loss[:,0]

# %%
from keras.optimizers import SGD,Adam
sgd = SGD(lr = config.LEARNING_RATE, decay=1e-6, momentum=config.LEARNING_MOMENTUM, nesterov=True)

# %%
# g_model.compile(optimizer=sgd, loss= 'categorical_crossentropy', metrics=['accuracy'])
# g_model.compile(optimizer=sgd, loss= 'binary_crossentropy_with_logits', metrics=['accuracy'])
g_model.compile(optimizer=sgd, loss= loss_func, metrics=['accuracy'])
# Out:
# Tensor("loss_27/activation_364_loss/Cast_1:0", shape=(?, ?, ?), dtype=bool)
# Tensor("loss_27/activation_364_loss/clip_by_value:0", shape=(?, 81), dtype=float32)
# Tensor("loss_27/activation_364_loss/add:0", shape=(?, 81, 3136), dtype=float32)
# Tensor("loss_27/activation_364_loss/truediv_2:0", shape=(?, 81), dtype=float32)

# %%
g_model.fit_generator(train_generator,
            epochs=50,
            steps_per_epoch=100)
# Out:
# Epoch 1/50
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/scipy/ndimage/interpolation.py:616: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# 100/100 [==============================] - 69s 688ms/step - loss: 1.3908 - acc: 3.0014e-04
# Epoch 4/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4638 - acc: 2.4195e-04
# Epoch 5/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4035 - acc: 1.8575e-04
# Epoch 6/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4256 - acc: 2.6068e-04
# Epoch 7/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3844 - acc: 3.5834e-04
# Epoch 8/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3987 - acc: 2.5989e-04
# Epoch 9/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3761 - acc: 3.3841e-04
# Epoch 10/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3948 - acc: 3.1848e-04
# Epoch 11/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3664 - acc: 2.2840e-04
# Epoch 12/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.3698 - acc: 2.3517e-04
# Epoch 13/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.4028 - acc: 1.9770e-04
# Epoch 14/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3756 - acc: 2.8380e-04
# Epoch 15/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4175 - acc: 2.3278e-04
# Epoch 16/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4281 - acc: 2.4434e-04
# Epoch 17/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4242 - acc: 1.5824e-04
# Epoch 18/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.4039 - acc: 2.7384e-04
# Epoch 19/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.4392 - acc: 2.5630e-04
# Epoch 20/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3790 - acc: 2.3318e-04
# Epoch 21/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.4128 - acc: 2.3318e-04
# Epoch 22/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3914 - acc: 2.5151e-04
# Epoch 23/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.4051 - acc: 3.0652e-04
# Epoch 24/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.3591 - acc: 2.4115e-04
# Epoch 25/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.3975 - acc: 2.2521e-04
# Epoch 26/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.3958 - acc: 3.2685e-04
# Epoch 27/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3514 - acc: 2.5949e-04
# Epoch 28/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4035 - acc: 2.5311e-04
# Epoch 29/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3934 - acc: 1.7897e-04
# Epoch 30/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3854 - acc: 3.2565e-04
# Epoch 31/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3561 - acc: 1.6342e-04
# Epoch 32/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4282 - acc: 3.2725e-04
# Epoch 33/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4030 - acc: 1.3512e-04
# Epoch 34/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3857 - acc: 3.0891e-04
# Epoch 35/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3898 - acc: 2.8221e-04
# Epoch 36/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3944 - acc: 2.3637e-04
# Epoch 37/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3949 - acc: 2.6706e-04
# Epoch 38/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3886 - acc: 2.4155e-04
# Epoch 39/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3728 - acc: 1.6263e-04
# Epoch 40/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3499 - acc: 2.1046e-04
# Epoch 41/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4151 - acc: 2.2481e-04
# Epoch 42/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4045 - acc: 2.4912e-04
# Epoch 43/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3744 - acc: 1.2317e-04
# Epoch 44/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3909 - acc: 2.2879e-04
# Epoch 45/50
# 100/100 [==============================] - 69s 688ms/step - loss: 1.3659 - acc: 2.1524e-04
# Epoch 46/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4047 - acc: 1.6303e-04
# Epoch 47/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3643 - acc: 2.8380e-04
# Epoch 48/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3724 - acc: 2.0448e-04
# Epoch 49/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.4152 - acc: 2.2162e-04
# Epoch 50/50
# 100/100 [==============================] - 69s 689ms/step - loss: 1.3331 - acc: 2.7264e-04

# %% [markdown]
# # Test

# %%
from utils.datagenerator import load_image_gt
import numpy as np
import random

# %%
image, gt_class_ids, gt_masks, gt_all_masks = \
                load_image_gt(dataset_train, config, random.randint(0,150), augment=True,
                          use_mini_mask=config.USE_MINI_MASK,use_background=True)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/scipy/ndimage/interpolation.py:616: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)

# %%
# %matplotlib notebook
plt.imshow(image)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.expand_dims(image, axis=0)
output_mask = g_model.predict(x)
print(output_mask.shape)
output_mask = np.reshape(output_mask[0,:,:],(56,56,81))
# Out:
# (1, 3136, 81)

# %%
gt_class_ids
# Out:
# array([ 1, 38, 60,  1,  1], dtype=int32)

# %%
#before train
# %matplotlib notebook
plt.imshow(gt_masks[:,:,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#binary cross entropy *50
# %matplotlib notebook
plt.imshow(output_mask[:,:,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#y_true * tf.log(y_pred) *50
# %matplotlib notebook
plt.imshow(output_mask[:,:,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#y_true * tf.log(y_pred) + (1 - y_true) * tf.log(1 - y_pred) * 50
# %matplotlib notebook
plt.imshow(output_mask[:,:,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
