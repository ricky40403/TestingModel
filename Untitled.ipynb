# %%
# from utils import datagenerator
from utils.shape import ShapesConfig
from coco import CocoDataset
import matplotlib.pyplot as plt
from utils.datagenerator import data_generator

from keras.applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
import keras.layers as KL
import keras.models as KM
# import utils
# Out:
# Using TensorFlow backend.
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
config = ShapesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE_SHAPES                [[56 56]
#  [28 28]
#  [14 14]
#  [ 7  7]
#  [ 4  4]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [ 0.1  0.1  0.2  0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# GPU_COUNT                      1
# IMAGES_PER_GPU                 8
# IMAGE_MAX_DIM                  224
# IMAGE_MIN_DIM                  224
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [224 224   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.002
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [ 123.7  116.8  103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           shapes
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              2
# RPN_BBOX_STD_DEV               [ 0.1  0.1  0.2  0.2]
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %%
dataset_train = CocoDataset()
dataset_train.load_coco('coco_dataset/', "val")
dataset_train.prepare()
# Out:
# loading annotations into memory...
# Done (t=0.68s)
# creating index...
# index created!

# %%
train_generator = data_generator(dataset_train, config, shuffle=True,batch_size=config.BATCH_SIZE)

# %%
############################################################
#  Resnet Graph
############################################################

# Code adopted from:
# https://github.com/fchollet/deep-learning-models/blob/master/resnet50.py

def identity_block(input_tensor, kernel_size, filters, stage, block,
                   use_bias=True):
    """The identity_block is the block that has no conv layer at shortcut
    # Arguments
        input_tensor: input tensor
        kernel_size: defualt 3, the kernel size of middle conv layer at main path
        filters: list of integers, the nb_filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    """
    nb_filter1, nb_filter2, nb_filter3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = KL.Conv2D(nb_filter1, (1, 1), name=conv_name_base + '2a',
                  use_bias=use_bias)(input_tensor)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter2, (kernel_size, kernel_size), padding='same',
                  name=conv_name_base + '2b', use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter3, (1, 1), name=conv_name_base + '2c',
                  use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    x = KL.Add()([x, input_tensor])
    x = KL.Activation('relu', name='res' + str(stage) + block + '_out')(x)
    return x


def conv_block(input_tensor, kernel_size, filters, stage, block,
               strides=(2, 2), use_bias=True):
    """conv_block is the block that has a conv layer at shortcut
    # Arguments
        input_tensor: input tensor
        kernel_size: defualt 3, the kernel size of middle conv layer at main path
        filters: list of integers, the nb_filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    Note that from stage 3, the first conv layer at main path is with subsample=(2,2)
    And the shortcut should have subsample=(2,2) as well
    """
    nb_filter1, nb_filter2, nb_filter3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'


    x = KL.Conv2D(nb_filter1, (1, 1), strides=strides,
                  name=conv_name_base + '2a', use_bias=use_bias)(input_tensor)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter2, (kernel_size, kernel_size), padding='same',
                  name=conv_name_base + '2b', use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = KL.Activation('relu')(x)

    x = KL.Conv2D(nb_filter3, (1, 1), name=conv_name_base +
                  '2c', use_bias=use_bias)(x)
    x = KL.BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    shortcut = KL.Conv2D(nb_filter3, (1, 1), strides=strides,
                         name=conv_name_base + '1', use_bias=use_bias)(input_tensor)
    shortcut = KL.BatchNormalization(axis=3, name=bn_name_base + '1')(shortcut)

    x = KL.Add()([x, shortcut])
    x = KL.Activation('relu', name='res' + str(stage) + block + '_out')(x)
    return x


def resnet_graph(input_image, architecture, input_shape = None, stage5=False,include_top=True,weights='imagenet'):
    assert architecture in ["resnet50", "resnet101"]
    pool_size = (2,2)

    input_shape = _obtain_input_shape(input_shape,
                                     default_size=224,
                                     min_size=197,
                                     data_format=K.image_data_format(),
                                      require_flatten=include_top,
                                      weights=weights)
    print("input_image : {} ".format(input_image))
     # Stage 1
    x = KL.ZeroPadding2D((3, 3))(input_image)
    x = KL.Conv2D(64, (7, 7), strides=(2, 2), name='conv1', use_bias=True)(x)
    x = KL.BatchNormalization(axis=3, name='bn_conv1')(x)
    x = KL.Activation('relu')(x)
    C1 = x = KL.MaxPooling2D((3, 3), strides=(2, 2), padding="same")(x)
    
#     C1 = x , mask_1 = MaxPoolingWithArgmax2D((3,3))(x)
   
    
    print("C1 : {} ".format(C1))
    # Stage 2
    x = conv_block(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='b')
    C2 = x = identity_block(x, 3, [64, 64, 256], stage=2, block='c')
    
    #C2 , mask_2 = MaxPoolingWithArgmax2D((2,2))(x)
    print("C2 : {} ".format(C2))
    
    # Stage 3
    x = conv_block(x, 3, [128, 128, 512], stage=3, block='a')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='b')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='c')
    C3 = x = identity_block(x, 3, [128, 128, 512], stage=3, block='d')
    
    #C3 , mask_3 = MaxPoolingWithArgmax2D((2,2))(x)
    print("C3 : {} ".format(C3))
    
    # Stage 4
    x = conv_block(x, 3, [256, 256, 1024], stage=4, block='a')
    block_count = {"resnet50": 5, "resnet101": 22}[architecture]
    for i in range(block_count):
        x = identity_block(x, 3, [256, 256, 1024], stage=4, block=chr(98 + i))
    C4 = x
    
    #C4 , mask_4 = MaxPoolingWithArgmax2D((2,2))(x)
    
    print("C4 : {} ".format(C4))
    # Stage 5
    if stage5:
        x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
        x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
        C5 = x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')
    else:
        C5 = None
        
#     C5 , mask_5 = MaxPoolingWithArgmax2D((2,2))(x)
    print("C5 : {} ".format(C5))
    
    
    
    xfc = KL.AveragePooling2D((7,7), name='avg_pool')(x)
    xfc = KL.Flatten()(xfc)
    print("xfc Flatten : {} ".format(xfc))
    xfc_out = xfc
    model6 = KM.Model(input_image,xfc)
    
#     xfc = KL.Dense(2048, activation='softmax', name='fc1000')(xfc)
    xfc = KL.Dense(1000, activation='softmax', name='fc1000')(xfc)
    print("xfc Dense : {} ".format(xfc))    

    model = KM.Model(input_image,xfc)
    weights_path = 'keras_resnet50_weight.hdf5'
    model.load_weights(weights_path,by_name=True)
    
    return model,C1,C2,C3,C4,C5#,mask_1#,mask_2,mask_3,mask_4

# %%
def generate_model(input_image):
    
    pool_size = (2,2)
    
    
    #resnet
    res_model,C1,C2,C3,C4,C5 = resnet_graph(input_image, "resnet50", stage5=True)
    weights_path = 'keras_resnet50_weight.hdf5'
    res_model.load_weights(weights_path,by_name=True)
    
    #7*7*1024
    y = KL.Conv2D(2048, (2, 2) , padding="same")(C5)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    
    y = KL.UpSampling2D(size=(2, 2))(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    
    #14*14*1024
    y = KL.Conv2D(1024, (2, 2) , padding="same")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    
    #14*14*1024
    y = KL.Conv2D(1024, (2, 2) , padding="same")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    print("y : {} ".format(y))
    
    y = KL.UpSampling2D(size=(2, 2))(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
   
    #28*28*512
    y = KL.Conv2D(512, (2, 2) , padding="same")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
   #28*28*512
    y = KL.Conv2D(512, (2, 2) , padding="same")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    
    y = KL.UpSampling2D(size=(2, 2))(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    
    #56*56*256
    y = KL.Conv2D(256,(2, 2) , padding="same")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    #56*56*256
    y = KL.Conv2D(128,(2, 2) , padding="same")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    
    #56*56*256
    y = KL.Conv2D(81,(2, 2) , padding="same")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    
    #56*56*256
    y = KL.Conv2D(81,(1, 1) , padding="valid")(y)
    y = KL.BatchNormalization(axis=3)(y)
    y = KL.Activation('relu')(y)
    print("y : {} ".format(y))
    
    y = KL.Reshape((56*56,81) , input_shape= (56,56,81))(y)
    print("y : {} ".format(y))
#     y = KL.Activation('softmax')(y)
#     print("y : {} ".format(y))
    
    
    model = KM.Model(input_image,y)
    return model

# %%
input_image = KL.Input(shape=[224,224,3], name="g_input_data")
g_model = generate_model(input_image)
# Out:
# input_image : Tensor("g_input_data_1:0", shape=(?, 224, 224, 3), dtype=float32)
# C1 : Tensor("max_pooling2d_2/MaxPool:0", shape=(?, 56, 56, 64), dtype=float32)
# C2 : Tensor("res2c_out_1/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# C3 : Tensor("res3d_out_1/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# C4 : Tensor("res4f_out_1/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# C5 : Tensor("res5c_out_1/Relu:0", shape=(?, 7, 7, 2048), dtype=float32)
# xfc Flatten : Tensor("flatten_2/Reshape:0", shape=(?, ?), dtype=float32)
# xfc Dense : Tensor("fc1000_1/Softmax:0", shape=(?, 1000), dtype=float32)
# y : Tensor("activation_80/Relu:0", shape=(?, 7, 7, 2048), dtype=float32)
# y : Tensor("activation_81/Relu:0", shape=(?, 14, 14, 2048), dtype=float32)
# y : Tensor("activation_82/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# y : Tensor("activation_83/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# y : Tensor("activation_83/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# y : Tensor("activation_85/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# y : Tensor("activation_86/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# y : Tensor("activation_88/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# y : Tensor("activation_89/Relu:0", shape=(?, 56, 56, 128), dtype=float32)
# y : Tensor("activation_90/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y : Tensor("activation_91/Relu:0", shape=(?, 56, 56, 81), dtype=float32)
# y : Tensor("reshape_2/Reshape:0", shape=(?, 3136, 81), dtype=float32)

# %%
g_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# g_input_data (InputLayer)       (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 230, 230, 3)  0           g_input_data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_out (Activation)          (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       res2a_out[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  res2a_out[0][0]
# __________________________________________________________________________________________________
# res2b_out (Activation)          (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       res2b_out[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  res2b_out[0][0]
# __________________________________________________________________________________________________
# res2c_out (Activation)          (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       res2c_out[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_9[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      res2c_out[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_out (Activation)          (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       res3a_out[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_11[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  res3a_out[0][0]
# __________________________________________________________________________________________________
# res3b_out (Activation)          (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       res3b_out[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  res3b_out[0][0]
# __________________________________________________________________________________________________
# res3c_out (Activation)          (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       res3c_out[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  res3c_out[0][0]
# __________________________________________________________________________________________________
# res3d_out (Activation)          (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      res3d_out[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_16[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_17[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      res3d_out[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_out (Activation)          (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4a_out[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_18[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_19[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  res4a_out[0][0]
# __________________________________________________________________________________________________
# res4b_out (Activation)          (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4b_out[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_20[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_21[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  res4b_out[0][0]
# __________________________________________________________________________________________________
# res4c_out (Activation)          (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4c_out[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  res4c_out[0][0]
# __________________________________________________________________________________________________
# res4d_out (Activation)          (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4d_out[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_24[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  res4d_out[0][0]
# __________________________________________________________________________________________________
# res4e_out (Activation)          (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      res4e_out[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  res4e_out[0][0]
# __________________________________________________________________________________________________
# res4f_out (Activation)          (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      res4f_out[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_28[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_29[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     res4f_out[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_out (Activation)          (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     res5a_out[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_30[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_31[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  res5a_out[0][0]
# __________________________________________________________________________________________________
# res5b_out (Activation)          (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     res5b_out[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_32[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_33[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  res5b_out[0][0]
# __________________________________________________________________________________________________
# res5c_out (Activation)          (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 2048)   16779264    res5c_out[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, 7, 2048)   8192        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 7, 7, 2048)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 2048) 0           activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 2048) 8192        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 2048) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 1024) 8389632     activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 1024) 4096        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 1024) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 1024) 4195328     activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 1024) 0           activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 1024) 4096        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 1024) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 512)  2097664     activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 512)  2048        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 28, 28, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 512)  1049088     activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 512)  2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 28, 28, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 512)  0           activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 512)  2048        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 56, 56, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 256)  524544      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 56, 56, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  131200      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 81)   41553       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 81)   324         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 56, 56, 81)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 81)   6642        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 81)   324         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 56, 56, 81)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 3136, 81)     0           activation_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 3136, 81)     0           reshape_1[0][0]
# ==================================================================================================
# Total params: 56,839,627
# Trainable params: 56,768,007
# Non-trainable params: 71,620
# __________________________________________________________________________________________________

# %%
def loss_per_class(y_true, y_pred):
    #caculate all classes' category loss

# %%
from keras.metrics import binary_accuracy

# %%
from keras.optimizers import SGD,Adam
sgd = SGD(lr = config.LEARNING_RATE, decay=1e-6, momentum=config.LEARNING_MOMENTUM, nesterov=True)

# %%
g_model.compile(optimizer=sgd, loss= 'categorical_crossentropy', metrics=['accuracy'])
# g_model.compile(optimizer=sgd, loss= binary_crossentropy_with_logits, metrics=[binary_accuracy])
# g_model.compile(optimizer=sgd, loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
g_model.fit_generator(train_generator,
            epochs=150,
            steps_per_epoch=100)
# Out:
# Epoch 1/150
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/scipy/ndimage/interpolation.py:616: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# 100/100 [==============================] - 95s 948ms/step - loss: 0.5101 - acc: 0.0453
# Epoch 2/150
# 100/100 [==============================] - 80s 802ms/step - loss: 0.2496 - acc: 0.0954
# Epoch 3/150
# 100/100 [==============================] - 80s 803ms/step - loss: 0.2050 - acc: 0.0967
# Epoch 4/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1773 - acc: 0.0981
# Epoch 5/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1592 - acc: 0.1000
# Epoch 6/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1525 - acc: 0.1001
# Epoch 7/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1965 - acc: 0.0921
# Epoch 8/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1611 - acc: 0.0989
# Epoch 9/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1817 - acc: 0.0942
# Epoch 10/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1606 - acc: 0.0986
# Epoch 11/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1800 - acc: 0.0957
# Epoch 12/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1742 - acc: 0.0958
# Epoch 13/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1568 - acc: 0.1043
# Epoch 14/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1731 - acc: 0.1038
# Epoch 15/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1723 - acc: 0.1078
# Epoch 16/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1571 - acc: 0.1080
# Epoch 17/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1268 - acc: 0.1135
# Epoch 18/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1720 - acc: 0.1086
# Epoch 19/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1550 - acc: 0.1083
# Epoch 20/150
# 100/100 [==============================] - 81s 808ms/step - loss: 0.1564 - acc: 0.1103
# Epoch 21/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1270 - acc: 0.1094
# Epoch 22/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1633 - acc: 0.1070
# Epoch 23/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1684 - acc: 0.1177
# Epoch 24/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1276 - acc: 0.1101
# Epoch 25/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1521 - acc: 0.1134
# Epoch 26/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1731 - acc: 0.1238
# Epoch 27/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1582 - acc: 0.1227
# Epoch 28/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1488 - acc: 0.1196
# Epoch 29/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1493 - acc: 0.1318
# Epoch 30/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1577 - acc: 0.1330
# Epoch 31/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1506 - acc: 0.1252
# Epoch 32/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1591 - acc: 0.1137
# Epoch 33/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1601 - acc: 0.1146
# Epoch 34/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1516 - acc: 0.1303
# Epoch 35/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1393 - acc: 0.1239
# Epoch 36/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1360 - acc: 0.1166
# Epoch 37/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1699 - acc: 0.1411
# Epoch 38/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1392 - acc: 0.1292
# Epoch 39/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1416 - acc: 0.1265
# Epoch 40/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1672 - acc: 0.1234
# Epoch 41/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1371 - acc: 0.1221
# Epoch 42/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1660 - acc: 0.1512
# Epoch 43/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1518 - acc: 0.1314
# Epoch 44/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1591 - acc: 0.1324
# Epoch 45/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1442 - acc: 0.1383
# Epoch 46/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1419 - acc: 0.1351
# Epoch 47/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1361 - acc: 0.1351
# Epoch 48/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1341 - acc: 0.1211
# Epoch 49/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1382 - acc: 0.1292
# Epoch 50/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1555 - acc: 0.1365
# Epoch 51/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1498 - acc: 0.1342
# Epoch 52/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1455 - acc: 0.1226
# Epoch 53/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1531 - acc: 0.1290
# Epoch 54/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1572 - acc: 0.1413
# Epoch 55/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1574 - acc: 0.1313
# Epoch 56/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1457 - acc: 0.1416
# Epoch 57/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1362 - acc: 0.1289
# Epoch 58/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1349 - acc: 0.1278
# Epoch 59/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1409 - acc: 0.1281
# Epoch 60/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1439 - acc: 0.1264
# Epoch 61/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1227 - acc: 0.1283
# Epoch 62/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1358 - acc: 0.1288
# Epoch 63/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1481 - acc: 0.1329
# Epoch 64/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1291 - acc: 0.1316
# Epoch 65/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1298 - acc: 0.1367
# Epoch 66/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1434 - acc: 0.1362
# Epoch 67/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1385 - acc: 0.1405
# Epoch 68/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1302 - acc: 0.1298
# Epoch 69/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1293 - acc: 0.1354
# Epoch 70/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1475 - acc: 0.1362
# Epoch 71/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1497 - acc: 0.1306
# Epoch 72/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1202 - acc: 0.1332
# Epoch 73/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1308 - acc: 0.1217
# Epoch 74/150
# 100/100 [==============================] - 81s 807ms/step - loss: 0.1649 - acc: 0.1220
# Epoch 75/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1167 - acc: 0.1333
# Epoch 76/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1427 - acc: 0.1333
# Epoch 77/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1278 - acc: 0.1315
# Epoch 78/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1314 - acc: 0.1362
# Epoch 79/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1500 - acc: 0.1342
# Epoch 80/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1477 - acc: 0.1242
# Epoch 81/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1380 - acc: 0.1273
# Epoch 82/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1163 - acc: 0.1256
# Epoch 83/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1503 - acc: 0.1316
# Epoch 84/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1331 - acc: 0.1325
# Epoch 85/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1484 - acc: 0.1363
# Epoch 86/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1506 - acc: 0.1404
# Epoch 87/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1373 - acc: 0.1314
# Epoch 88/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1356 - acc: 0.1330
# Epoch 89/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1427 - acc: 0.1347
# Epoch 90/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1357 - acc: 0.1304
# Epoch 91/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1388 - acc: 0.1401
# Epoch 92/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1368 - acc: 0.1379
# Epoch 93/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1169 - acc: 0.1313
# Epoch 94/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1393 - acc: 0.1473
# Epoch 95/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1347 - acc: 0.1486
# Epoch 96/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1172 - acc: 0.1363
# Epoch 97/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1419 - acc: 0.1317
# Epoch 98/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1448 - acc: 0.1277
# Epoch 99/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1289 - acc: 0.1284
# Epoch 100/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1343 - acc: 0.1307
# Epoch 101/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1199 - acc: 0.1266
# Epoch 102/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1202 - acc: 0.1296
# Epoch 103/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1422 - acc: 0.1355
# Epoch 104/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1203 - acc: 0.1268
# Epoch 105/150
# 100/100 [==============================] - 80s 804ms/step - loss: 0.1353 - acc: 0.1252
# Epoch 106/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1384 - acc: 0.1391
# Epoch 107/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1270 - acc: 0.1303
# Epoch 108/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1334 - acc: 0.1534
# Epoch 109/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1233 - acc: 0.1386
# Epoch 110/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1366 - acc: 0.1422
# Epoch 111/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1163 - acc: 0.1314
# Epoch 112/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1343 - acc: 0.1363
# Epoch 113/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1172 - acc: 0.1454
# Epoch 114/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1318 - acc: 0.1378
# Epoch 115/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1293 - acc: 0.1374
# Epoch 116/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1335 - acc: 0.1428
# Epoch 117/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1214 - acc: 0.1422
# Epoch 118/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1253 - acc: 0.1440
# Epoch 119/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1316 - acc: 0.1348
# Epoch 120/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1230 - acc: 0.1377
# Epoch 121/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1321 - acc: 0.1289
# Epoch 122/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1305 - acc: 0.1316
# Epoch 123/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1259 - acc: 0.1483
# Epoch 124/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1160 - acc: 0.1312
# Epoch 125/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1506 - acc: 0.1544
# Epoch 126/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1346 - acc: 0.1528
# Epoch 127/150
# 100/100 [==============================] - 80s 805ms/step - loss: 0.1433 - acc: 0.1523
# Epoch 128/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1314 - acc: 0.1417
# Epoch 129/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1288 - acc: 0.1546
# Epoch 130/150
# 100/100 [==============================] - 81s 805ms/step - loss: 0.1142 - acc: 0.1467
# Epoch 131/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1198 - acc: 0.1398
# Epoch 132/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1143 - acc: 0.1402
# Epoch 133/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1226 - acc: 0.1273
# Epoch 134/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1381 - acc: 0.1427
# Epoch 135/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1343 - acc: 0.1372
# Epoch 136/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1355 - acc: 0.1523
# Epoch 137/150
# 100/100 [==============================] - 81s 806ms/step - loss: 0.1169 - acc: 0.1428
# Epoch 138/150
#  94/100 [===========================>..] - ETA: 4s - loss: 0.1309 - acc: 0.1411
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d3c3d3f0b78b> in <module>()
#       1 g_model.fit_generator(train_generator,
#       2             epochs=150,
# ----> 3             steps_per_epoch=100)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2094                     outs = self.train_on_batch(x, y,
#    2095                                                sample_weight=sample_weight,
# -> 2096                                                class_weight=class_weight)
#    2097
#    2098                     if not isinstance(outs, list):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1812             ins = x + y + sample_weights
#    1813         self._make_train_function()
# -> 1814         outputs = self.train_function(ins)
#    1815         if len(outputs) == 1:
#    1816             return outputs[0]
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2350         session = get_session()
#    2351         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2352                               **self.session_kwargs)
#    2353         return updated[:len(self.outputs)]
#    2354
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
from utils.datagenerator import load_image_gt
import numpy as np

# %%
image, gt_class_ids, gt_masks, gt_all_masks = \
                load_image_gt(dataset_train, config, 130, augment=True,
                          use_mini_mask=config.USE_MINI_MASK,use_background=True)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/scipy/ndimage/interpolation.py:616: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)

# %%
# %matplotlib notebook
plt.imshow(image)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
gt_class_ids
# Out:
# array([58,  1,  1, 66,  1], dtype=int32)

# %%
x = np.expand_dims(image, axis=0)
output_mask = g_model.predict(x)
output_mask = np.reshape(output_mask[0,:,:],(56,56,81))

# %%
final_mask = np.zeros((56,56))
for i in range(0,output_mask.shape[0]):
    for j in range(0,output_mask.shape[1]):
        for k in range(0,output_mask.shape[2]):
            if(k == np.argmax(output_mask[i,j,:])):
                if k== 0:
                    final_mask[i,j] = 255
                else:
                    final_mask[i,j] = k
                    
                output_mask[i,j,k] = 1
            else:
                output_mask[i,j,k] = 0

# %%
#using generator
# %matplotlib notebook
plt.imshow(gt_masks[:,:,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#using generator with softmax activate function
# %matplotlib notebook
plt.imshow(output_mask[:,:,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Test to fit one pic

# %%
x = np.expand_dims(image, axis=0)
y = np.expand_dims(gt_masks, axis=0)

# %%
y.shape
# Out:
# (1, 56, 56, 81)

# %%
y = np.reshape(y,(1,56*56,81))

# %%
y.shape
# Out:
# (1, 3136, 81)

# %%
for i in range(0,200):
    g_model.fit(x,y)
# Out:
# Epoch 1/1
# 1/1 [==============================] - 0s 272ms/step - loss: 0.5762 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 241ms/step - loss: 0.5756 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 220ms/step - loss: 0.5750 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 205ms/step - loss: 0.5745 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5739 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5734 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5728 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5723 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5717 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5712 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5707 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5701 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5696 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5691 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5686 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5681 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5675 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 205ms/step - loss: 0.5670 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5665 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5660 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5655 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5650 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5645 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5641 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5636 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5631 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5626 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5621 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5617 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5612 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 216ms/step - loss: 0.5607 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 211ms/step - loss: 0.5603 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 207ms/step - loss: 0.5598 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 207ms/step - loss: 0.5594 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 206ms/step - loss: 0.5589 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5585 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5580 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5576 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5571 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5567 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5563 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5558 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5554 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5550 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5545 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 206ms/step - loss: 0.5541 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5537 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5533 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5529 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 207ms/step - loss: 0.5524 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5520 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5516 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5512 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5508 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5504 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5500 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5496 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 205ms/step - loss: 0.5492 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5488 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5485 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5481 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5477 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5473 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5469 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 206ms/step - loss: 0.5466 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5462 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5458 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5454 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5451 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5447 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5444 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5440 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5436 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5433 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5429 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5426 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 206ms/step - loss: 0.5422 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5419 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5415 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5412 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5409 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5405 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5402 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5398 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5395 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5392 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5388 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5385 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5382 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5379 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5375 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5372 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5369 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5366 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5363 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5360 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5356 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5353 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5350 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 206ms/step - loss: 0.5347 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5344 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5341 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5338 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5335 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5332 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5329 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 200ms/step - loss: 0.5326 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5323 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5320 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5317 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5315 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5312 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5309 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5306 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5303 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5300 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5298 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5295 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5292 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5289 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5287 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 206ms/step - loss: 0.5284 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5281 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5278 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5276 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5273 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5270 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5268 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5265 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5263 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5260 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5257 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5255 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5252 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5250 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5247 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5245 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5242 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5240 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5237 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5235 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5232 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5230 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5227 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5225 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5223 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5220 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5218 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5215 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 207ms/step - loss: 0.5213 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5211 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5208 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5206 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5204 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5201 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5199 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5197 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5195 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5192 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5190 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5188 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5186 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5184 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5181 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 205ms/step - loss: 0.5179 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5177 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5175 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5173 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5170 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5168 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5166 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5164 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5162 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5160 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5158 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5156 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5154 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5152 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5149 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5147 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 205ms/step - loss: 0.5145 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5143 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5141 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5139 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5137 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5135 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5133 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5131 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5129 - acc: 0.6008
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5128 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5126 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 205ms/step - loss: 0.5124 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5122 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5120 - acc: 0.5998
# Epoch 1/1
# 1/1 [==============================] - 0s 201ms/step - loss: 0.5118 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5116 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5114 - acc: 0.6004
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5112 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 204ms/step - loss: 0.5110 - acc: 0.6001
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.5109 - acc: 0.6001

# %%
output_mask = g_model.predict(x)

# %%
output_mask.shape
# Out:
# (1, 3136, 81)

# %%
output_mask = np.reshape(output_mask[0,:,:],(56,56,81))

# %%
output_mask.shape
# Out:
# (56, 56, 81)

# %%
final_mask = np.zeros((56,56))
for i in range(0,output_mask.shape[0]):
    for j in range(0,output_mask.shape[1]):
        for k in range(0,output_mask.shape[2]):
            if(k == np.argmax(output_mask[i,j,:])):
                if k== 0:
                    final_mask[i,j] = 255
                else:
                    final_mask[i,j] = k
                    
                output_mask[i,j,k] = 1
            else:
                output_mask[i,j,k] = 0

# %%
#200 without background
# %matplotlib notebook
plt.imshow(final_mask)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#400 without background
# %matplotlib notebook
plt.imshow(final_mask)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#600 without background
# %matplotlib notebook
plt.imshow(final_mask)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#200 with background
# %matplotlib notebook
plt.imshow(final_mask)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#400 with background
# %matplotlib notebook
plt.imshow(final_mask)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#600 with background
# %matplotlib notebook
plt.imshow(final_mask)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
